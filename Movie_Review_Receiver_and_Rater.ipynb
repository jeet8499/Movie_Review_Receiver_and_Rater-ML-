# %% [markdown]
# <a href="https://colab.research.google.com/github/jeet8499/Movie_Review_Receiver_and_Rater-ML-/blob/main/Movie_Review_Receiver_and_Rater.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk scikit-learn

import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %% [markdown]
# stopwords → words like is, the, was are downloaded
#
# vader_lexicon → emotional dictionary with positive & negative words

# %% [markdown]
# | Library                      | Purpose                      |
# | ---------------------------- | ---------------------------- |
# | `nltk`                       | NLP processing               |
# | `re`                         | Removes numbers & patterns   |
# | `string`                     | Removes punctuation          |
# | `stopwords`                  | Removes common useless words |
# | `SentimentIntensityAnalyzer` | Analyzes emotions in text    |

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    words =text.split()
    words = [w for w in words if w not in stopwords.words('english')]
    return "".join(words)

# %% [markdown]
# | Step                | Action                | Result            |
# | ------------------- | --------------------- | ----------------- |
# | `lower()`           | Converts to lowercase | amazing           |
# | `re.sub()`          | Removes numbers       | removes 10        |
# | punctuation removal | Removes `! /`         | clean text        |
# | stopwords removal   | Removes *was, this*   | useful words only |

# %%
review = input("Enter your movie review: ")

# DO NOT use cleaned text for VADER
sia = SentimentIntensityAnalyzer()
sentiment_scores = sia.polarity_scores(review)

def sentiment_to_rating(compound_score):
    if compound_score >= 0.05:
        sentiment = "Positive 😊"
        rating = 5
    elif compound_score <= -0.05:
        sentiment = "Negative 😞"
        rating = 1
    else:
        sentiment = "Neutral 😐"
        rating = 3
    return sentiment, rating

sentiment, rating = sentiment_to_rating(sentiment_scores['compound'])

print("\n--- Movie Review Analysis ---")
print("Review:", review)
print("Compound Score:", sentiment_scores['compound'])
print("Sentiment:", sentiment)
print("Rating:", "⭐" * rating)
# Out:
# Enter your movie review: VERY VERY BAD AND BOARINNG MOVIE
#
# --- Movie Review Analysis ---
# Review: VERY VERY BAD AND BOARINNG MOVIE
# Compound Score: -0.6214
# Sentiment: Negative 😞
# Rating: ⭐

# %% [markdown]
# there was errore before in the code
# review =  input("enter your movie review:")
# clean_review = clean_text(review)
# sia = SentimentIntensityAnalyzer()
# sentiment_scores = sia.polarity_scores(clean_review)
#
# def sentiment_to_rating(compound_score):
#     if compound_score >= 0.05:
#         sentiment = "Positive 😊"
#         rating = 5  # Example rating for positive
#     elif compound_score <= -0.05:
#         sentiment = "Negative 😞"
#         rating = 1  # Example rating for negative
#     else:
#         sentiment = "Neutral 😐"
#         rating = 3  # Example rating for neutral
#     return sentiment, rating
#
# sentiment, rating = sentiment_to_rating(sentiment_scores['compound'])
#
# print("\n--- Movie Review Analysis ---")
# print("Sentiment:", sentiment)
# print("Rating:", "⭐" * rating)
#
# problem:
#  passing clean_review into VADER instead of the original review.
#
# sentiment_scores = sia.polarity_scores(clean_review)

# %% [markdown]
# | Compound Score | Rating | Meaning   |
# | -------------- | ------ | --------- |
# | ≥ 0.6          | ⭐⭐⭐⭐⭐  | Excellent |
# | ≥ 0.2          | ⭐⭐⭐⭐   | Good      |
# | -0.2 to 0.2    | ⭐⭐⭐    | Average   |
# | -0.6 to -0.2   | ⭐⭐     | Bad       |
# | < -0.6         | ⭐      | Very Bad  |
